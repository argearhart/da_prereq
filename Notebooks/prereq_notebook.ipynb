# %%
numbers = [12, 18, 25, 30, 42]

total = sum(numbers)
average = total / len(numbers)

print("Numbers:", numbers)
print("Total:", total)
print("Average:", average)
# Out:
# Numbers: [12, 18, 25, 30, 42]
# Total: 127
# Average: 25.4

# %% [markdown]
# ## Hello from Amanda
# ---
#
# Hi everyone! I'm **Amanda**, part of the Code:You team working as a **Community Coordinator**.
#
# I'm revisiting the **Data Analysis curriculum** to strengthen my Python and data analysis skills by completing the assignments alongside the cohort.
#
# I'm excited to dig back into the material and may jump in to mentor or help troubleshoot when I can.
#
# Looking forward to learning along with this group and seeing the projects everyone build.
